# %%
from euler_riemann_exact import euler_riemann_exact_plot
from euler_riemann_exact import euler_riemann_density_plot

# %%
euler_riemann_exact_plot(
    rho_l=1.0,
    u_l=0.0,
    p_l=1.0,
    rho_r=0.125,
    u_r=0.0,
    p_r=0.1,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.25,
)

tmp = euler_riemann_density_plot(
    rho_l=1.0,
    u_l=0.0,
    p_l=1.0,
    rho_r=0.125,
    u_r=0.0,
    p_r=0.1,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.25,
)
# tmp.save("demo1.gif")

# %%
euler_riemann_exact_plot(
    rho_l=1.0,
    u_l=-2.0,
    p_l=0.4,
    rho_r=1.0,
    u_r=2.0,
    p_r=0.4,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.15,
)

tmp = euler_riemann_density_plot(
    rho_l=1.0,
    u_l=-2.0,
    p_l=0.4,
    rho_r=1.0,
    u_r=2.0,
    p_r=0.4,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.15,
)
# tmp.save("demo2.gif")

# %%
euler_riemann_exact_plot(
    rho_l=1.0,
    u_l=0.0,
    p_l=1000.4,
    rho_r=1.0,
    u_r=0.0,
    p_r=0.01,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.012,
)

tmp = euler_riemann_density_plot(
    rho_l=1.0,
    u_l=0.0,
    p_l=1000.4,
    rho_r=1.0,
    u_r=0.0,
    p_r=0.01,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.012,
)
# tmp.save("demo3.gif")

# %%
euler_riemann_exact_plot(
    rho_l=1.0,
    u_l=0.0,
    p_l=0.01,
    rho_r=1.0,
    u_r=0.0,
    p_r=100.0,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.035,
)

tmp = euler_riemann_density_plot(
    rho_l=1.0,
    u_l=0.0,
    p_l=0.01,
    rho_r=1.0,
    u_r=0.0,
    p_r=100.0,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.035,
)
# tmp.save("demo4.gif")

# %%
euler_riemann_exact_plot(
    rho_l=5.99924,
    u_l=19.5975,
    p_l=460.894,
    rho_r=5.99242,
    u_r=-6.19633,
    p_r=46.0950,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.035,
)

tmp = euler_riemann_density_plot(
    rho_l=5.99924,
    u_l=19.5975,
    p_l=460.894,
    rho_r=5.99242,
    u_r=-6.19633,
    p_r=46.0950,
    x_l=0.0,
    x_r=1.0,
    x_c=0.5,
    t=0.035,
)
# tmp.save("demo5.gif")

# %%
euler_riemann_exact_plot(
    rho_l=0.445,
    u_l=0.698,
    p_l=3.528,
    rho_r=0.5,
    u_r=0.0,
    p_r=0.571,
    x_l=-1.0,
    x_r=1.0,
    x_c=0.0,
    t=0.2,
)

tmp = euler_riemann_density_plot(
    rho_l=0.445,
    u_l=0.698,
    p_l=3.528,
    rho_r=0.5,
    u_r=0.0,
    p_r=0.571,
    x_l=-1.0,
    x_r=1.0,
    x_c=0.0,
    t=0.2,
)
# tmp.save("demo6.gif")

# %%
euler_riemann_exact_plot(
    rho_l=1.0,
    u_l=3.0,
    p_l=1.0,
    rho_r=1.0,
    u_r=-3.0,
    p_r=1.0,
    x_l=-1.0,
    x_r=1.0,
    x_c=0.0,
    t=0.4,
)

tmp = euler_riemann_density_plot(
    rho_l=1.0,
    u_l=3.0,
    p_l=1.0,
    rho_r=1.0,
    u_r=-3.0,
    p_r=1.0,
    x_l=-1.0,
    x_r=1.0,
    x_c=0.0,
    t=0.4,
)
# tmp.save("demo7.gif")
